# %%
import pandas as pd
import numpy as np

from matplotlib import pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import classification_report, f1_score, precision_score, recall_score, accuracy_score
from sklearn.preprocessing import StandardScaler, MinMaxScaler

from sklearn.cluster import KMeans, AgglomerativeClustering
from sklearn.neighbors import KNeighborsClassifier

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
import xgboost as xgb
import catboost as catb
# Out:
# D:\Anaconda3\lib\site-packages\dask\config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}
# D:\Anaconda3\lib\site-packages\distributed\config.py:20: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   defaults = yaml.load(f)

# %%
# %matplotlib inline

# %%
data = pd.read_csv('course_project_train.csv')
X_test = pd.read_csv('course_project_test.csv')

# %%
train, valid = train_test_split(data, test_size=0.25, random_state=21)

# %% [markdown]
# Функции:

# %%
def modify_data(df, median_annual_income, median_accounts, median_months_delinquent, median_years_history, median_max_credit, 
                median_current_credit_balance, median_monthly_debt, median_bankruptcies):
    
    df.loc[df['Bankruptcies'].isnull(), 'Bankruptcies'] = median_bankruptcies
    df.loc[df['Annual Income'] > 5*10**6, 'Annual Income'] = median_annual_income
    df.loc[df['Number of Open Accounts'] > 30, 'Number of Open Accounts'] = median_accounts
    df.loc[df['Months since last delinquent'] > 100, 'Months since last delinquent'] = median_months_delinquent
    df.loc[df['Years of Credit History'] > 45, 'Years of Credit History'] = median_years_history
    df.loc[df['Maximum Open Credit'] > 10**7, 'Maximum Open Credit'] = median_max_credit
    df.loc[df['Current Credit Balance'] > 3*10**6, 'Current Credit Balance'] = median_current_credit_balance
    df.loc[df['Monthly Debt'] > 70000, 'Monthly Debt'] = median_monthly_debt
    
    df['Short Term'] = (df['Term'] == 'Short Term').astype(int)
    df = df.drop('Term', axis=1)

# %%
def get_classification_report(y_train_true, y_train_pred, y_test_true, y_test_pred):
    
    print('TRAIN\n\n' + classification_report(y_train_true, y_train_pred))
    print('TEST\n\n' + classification_report(y_test_true, y_test_pred))
    print('CONFUSION MATRIX\n')
    print(pd.crosstab(y_test_true, y_test_pred))

# %%
def get_balance(df, target_name):
    
    target_counts = df[target_name].value_counts()
    
    target_class_1 = target_counts.argmax()
    target_class_0 = target_counts.argmin()
    
    coeff = int(target_counts[target_class_1] / target_counts[target_class_0]) - 1
    
    for _ in range(coeff):
        add_sample = df[df[target_name] == target_class_0].sample(frac=1)
        df = df.append(add_sample, ignore_index=True)
    
    return df.sample(frac=1)

# %%
def show_proba_calibration(y_pred_proba, y_true_label, min_thr=0.1, max_thr=0.9):
    
    pred_true = np.array(list(zip(y_pred_proba, y_true_label)))
    
    thresholds = []
    precisions = []
    recalls = []
    f1_scores = []
    
    for threshold in np.linspace(min_thr, max_thr, 9):
        thresholds.append(threshold)
        precisions.append(precision_score(y_true_label, list(map(int, y_pred_proba > threshold))))
        recalls.append(recall_score(y_true_label, list(map(int, y_pred_proba > threshold))))
        f1_scores.append(f1_score(y_true_label, list(map(int, y_pred_proba > threshold))))
        
    plt.plot(thresholds, precisions, label='Precision')
    plt.plot(thresholds, recalls, label='Recall')
    plt.plot(thresholds, f1_scores, label='F1')
    
    plt.xlabel('Threshold')
    plt.ylabel('Scores')
    plt.legend()

# %%
def cluster_inertia(X, a=2, b=10):
    inertias = []

    for i in range(a, b):
        temp_model = KMeans(n_clusters=i, random_state=100)
        temp_model.fit(X)

        temp_inertia = temp_model.inertia_
        inertias.append(temp_inertia)

    plt.plot(range(a, b), inertias)
    plt.title('Inertia')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5625 entries, 4864 to 7113
# Data columns (total 17 columns):
# Home Ownership                  5625 non-null object
# Annual Income                   4439 non-null float64
# Years in current job            5348 non-null object
# Tax Liens                       5625 non-null float64
# Number of Open Accounts         5625 non-null float64
# Years of Credit History         5625 non-null float64
# Maximum Open Credit             5625 non-null float64
# Number of Credit Problems       5625 non-null float64
# Months since last delinquent    2569 non-null float64
# Bankruptcies                    5614 non-null float64
# Purpose                         5625 non-null object
# Term                            5625 non-null object
# Current Loan Amount             5625 non-null float64
# Current Credit Balance          5625 non-null float64
# Monthly Debt                    5625 non-null float64
# Credit Score                    4439 non-null float64
# Credit Default                  5625 non-null int64
# dtypes: float64(12), int64(1), object(4)
# memory usage: 791.0+ KB

# %%
train.describe()
# Out:
#        Annual Income    Tax Liens  Number of Open Accounts  \
# count   4.439000e+03  5625.000000              5625.000000
# mean    1.363759e+06     0.030044                11.152000
# std     8.279469e+05     0.264657                 4.935844
# min     1.645970e+05     0.000000                 2.000000
# 25%     8.401325e+05     0.000000                 8.000000
# 50%     1.171920e+06     0.000000                10.000000
# 75%     1.640460e+06     0.000000                14.000000
# max     1.014934e+07     6.000000                42.000000
#
#        Years of Credit History  Maximum Open Credit  \
# count              5625.000000         5.625000e+03
# mean                 18.335431         1.022467e+06
# std                   7.084915         1.848610e+07
# min                   4.000000         0.000000e+00
# 25%                  13.500000         2.801700e+05
# 50%                  17.000000         4.819100e+05
# 75%                  21.800000         7.930780e+05
# max                  57.700000         1.304726e+09
#
#        Number of Credit Problems  Months since last delinquent  Bankruptcies  \
# count                5625.000000                   2569.000000   5614.000000
# mean                    0.166044                     34.660179      0.113110
# std                     0.488654                     21.622976      0.336395
# min                     0.000000                      0.000000      0.000000
# 25%                     0.000000                     16.000000      0.000000
# 50%                     0.000000                     32.000000      0.000000
# 75%                     0.000000                     50.000000      0.000000
# max                     6.000000                    118.000000      4.000000
#
#        Current Loan Amount  Current Credit Balance   Monthly Debt  \
# count         5.625000e+03            5.625000e+03    5625.000000
# mean          1.177759e+07            2.893465e+05   18361.642667
# std           3.180890e+07            3.175926e+05   12032.974719
# min           2.147200e+04            0.000000e+00       0.000000
# 25%           1.814340e+05            1.140950e+05   10039.000000
# 50%           3.111020e+05            2.092850e+05   16087.000000
# 75%           5.265700e+05            3.605060e+05   23888.000000
# max           1.000000e+08            6.506797e+06  136679.000000
#
#        Credit Score  Credit Default
# count   4439.000000     5625.000000
# mean    1154.096418        0.280711
# std     1609.537996        0.449387
# min      585.000000        0.000000
# 25%      711.000000        0.000000
# 50%      731.000000        0.000000
# 75%      743.000000        1.000000
# max     7510.000000        1.000000

# %%
train.head()
# Out:
#      Home Ownership  Annual Income Years in current job  Tax Liens  \
# 4864           Rent      1599553.0              8 years        0.0
# 7199           Rent       886844.0               1 year        0.0
# 4716           Rent            NaN                  NaN        0.0
# 2560           Rent      1322419.0              2 years        0.0
# 3474           Rent       513095.0            10+ years        0.0
#
#       Number of Open Accounts  Years of Credit History  Maximum Open Credit  \
# 4864                      8.0                     19.2             872542.0
# 7199                      7.0                      6.6             225148.0
# 4716                      5.0                     51.5             485672.0
# 2560                      5.0                      4.5             242770.0
# 3474                      4.0                     13.2             143022.0
#
#       Number of Credit Problems  Months since last delinquent  Bankruptcies  \
# 4864                        0.0                          14.0           0.0
# 7199                        0.0                           NaN           0.0
# 4716                        0.0                          14.0           0.0
# 2560                        0.0                           NaN           0.0
# 3474                        0.0                           NaN           0.0
#
#                  Purpose        Term  Current Loan Amount  \
# 4864  debt consolidation   Long Term             535546.0
# 7199  debt consolidation   Long Term             262174.0
# 4716  debt consolidation   Long Term             614614.0
# 2560               other  Short Term             131252.0
# 3474  debt consolidation  Short Term           99999999.0
#
#       Current Credit Balance  Monthly Debt  Credit Score  Credit Default
# 4864                622440.0       41988.0         663.0               0
# 7199                113544.0       13820.0         688.0               1
# 4716                416518.0       16541.0           NaN               1
# 2560                 62054.0       10822.0         749.0               0
# 3474                113639.0       10775.0         727.0               0

# %%
train['Credit Default'].value_counts()
# Out:
# 0    4046
# 1    1579
# Name: Credit Default, dtype: int64

# %%
train['Credit Default'].value_counts()[0] / train['Credit Default'].value_counts()[1]
# Out:
# 2.5623812539582014

# %%
for cat_colname in train.select_dtypes(include='object'):
    print(cat_colname, '\n\n')
    print(train[cat_colname].value_counts())
    print('\n' + '*'*100, '\n')
# Out:
# Home Ownership
#
#
# Home Mortgage    2755
# Rent             2365
# Own Home          495
# Have Mortgage      10
# Name: Home Ownership, dtype: int64
#
# ****************************************************************************************************
#
# Years in current job
#
#
# 10+ years    1750
# 2 years       522
# 3 years       461
# < 1 year      425
# 5 years       397
# 1 year        380
# 6 years       341
# 4 years       332
# 7 years       282
# 8 years       261
# 9 years       197
# Name: Years in current job, dtype: int64
#
# ****************************************************************************************************
#
# Purpose
#
#
# debt consolidation      4470
# other                    501
# home improvements        308
# business loan             94
# buy a car                 73
# medical bills             51
# major purchase            26
# buy house                 25
# take a trip               25
# small business            20
# wedding                   11
# educational expenses       8
# moving                     7
# vacation                   5
# renewable energy           1
# Name: Purpose, dtype: int64
#
# ****************************************************************************************************
#
# Term
#
#
# Short Term    4166
# Long Term     1459
# Name: Term, dtype: int64
#
# ****************************************************************************************************

# %% [markdown]
# Признак **Term** имеет всего 2 значения. Можно вместо него ввести признак **Short Term**.

# %%
not_obj_col = train.select_dtypes(exclude='object').columns

# %%
for colname in not_obj_col:
    print(colname)
    sns.boxplot(train[colname])
    plt.show()
# Out:
# Annual Income
# Tax Liens
# Number of Open Accounts
# Years of Credit History
# Maximum Open Credit
# Number of Credit Problems
# Months since last delinquent
# Bankruptcies
# Current Loan Amount
# Current Credit Balance
# Monthly Debt
# Credit Score
# Credit Default

# %%
train[train['Bankruptcies'].isnull()]
# Out:
#      Home Ownership  Annual Income Years in current job  Tax Liens  \
# 3063           Rent       464474.0            10+ years        0.0
# 3401           Rent       326154.0              6 years        0.0
# 7379       Own Home       290415.0             < 1 year        0.0
# 100        Own Home       337079.0               1 year        0.0
# 898            Rent       739005.0              2 years        0.0
# 4334           Rent       772749.0             < 1 year        0.0
# 5566       Own Home            NaN             < 1 year        0.0
# 256            Rent       857660.0               1 year        0.0
# 3351  Home Mortgage      2226192.0              8 years        0.0
# 3496           Rent       233567.0               1 year        0.0
# 257   Home Mortgage            NaN              2 years        0.0
#
#       Number of Open Accounts  Years of Credit History  Maximum Open Credit  \
# 3063                      5.0                     14.9              38126.0
# 3401                      2.0                     19.1                  0.0
# 7379                     16.0                     12.5             116644.0
# 100                       9.0                     39.6             644204.0
# 898                      20.0                     18.3            2177758.0
# 4334                      9.0                     19.6             575124.0
# 5566                     12.0                     24.7             594594.0
# 256                       6.0                     19.7             291082.0
# 3351                     14.0                     23.3             792836.0
# 3496                      7.0                     11.7                  0.0
# 257                      15.0                     13.6            1556390.0
#
#       Number of Credit Problems  Months since last delinquent  Bankruptcies  \
# 3063                        0.0                           0.0           NaN
# 3401                        0.0                          77.0           NaN
# 7379                        0.0                           0.0           NaN
# 100                         0.0                           0.0           NaN
# 898                         0.0                           0.0           NaN
# 4334                        0.0                          19.0           NaN
# 5566                        0.0                           0.0           NaN
# 256                         0.0                           0.0           NaN
# 3351                        0.0                          73.0           NaN
# 3496                        0.0                           0.0           NaN
# 257                         0.0                           0.0           NaN
#
#                    Purpose        Term  Current Loan Amount  \
# 3063                 other  Short Term              44814.0
# 3401                 other  Short Term           99999999.0
# 7379        small business  Short Term              71170.0
# 100   educational expenses  Short Term           99999999.0
# 898     debt consolidation  Short Term             456808.0
# 4334    debt consolidation  Short Term             167882.0
# 5566                 other  Short Term              92620.0
# 256     debt consolidation  Short Term           99999999.0
# 3351    debt consolidation  Short Term             528968.0
# 3496  educational expenses  Short Term             210166.0
# 257     debt consolidation  Short Term             447480.0
#
#       Current Credit Balance  Monthly Debt  Credit Score  Credit Default
# 3063                 18373.0         929.0        7490.0               1
# 3401                     0.0        1245.0         712.0               0
# 7379                 55499.0        2953.0        7160.0               1
# 100                 224770.0        4326.0         734.0               0
# 898                 607487.0        9669.0         732.0               1
# 4334                152988.0        7792.0         729.0               0
# 5566                126331.0       11987.0           NaN               0
# 256                 236816.0        3488.0         743.0               0
# 3351                625157.0       23746.0         674.0               0
# 3496                     0.0           0.0         746.0               0
# 257                 524210.0       19613.0           NaN               0

# %% [markdown]
# Заменим пропуски медианным значением.

# %%
median_bankruptcies = train['Bankruptcies'].median()

# %%
train.loc[train['Annual Income'] > 5*10**6, :]
# Out:
#      Home Ownership  Annual Income Years in current job  Tax Liens  \
# 5774  Home Mortgage      7655480.0            10+ years        0.0
# 4491  Home Mortgage      8200229.0              2 years        0.0
# 7089           Rent      5759280.0              7 years        0.0
# 3446  Home Mortgage      6611810.0            10+ years        0.0
# 602   Home Mortgage      5631030.0               1 year        0.0
# 3269           Rent      6133922.0              9 years        0.0
# 4745       Own Home      6029954.0              4 years        0.0
# 6946       Own Home      6492395.0               1 year        0.0
# 7299           Rent      5289676.0              3 years        0.0
# 4445  Home Mortgage      5725194.0              2 years        0.0
# 2992  Home Mortgage      5573460.0            10+ years        0.0
# 5102       Own Home      7637240.0              3 years        0.0
# 1601           Rent      7999095.0            10+ years        0.0
# 4283  Home Mortgage      5165264.0            10+ years        0.0
# 3927  Home Mortgage      6222880.0            10+ years        0.0
# 5823  Home Mortgage      5493527.0            10+ years        0.0
# 5396  Home Mortgage      8710740.0              2 years        2.0
# 3081           Rent      7381842.0              7 years        0.0
# 5934  Home Mortgage      5703648.0            10+ years        0.0
# 6472           Rent     10149344.0              5 years        0.0
# 3550  Home Mortgage      6495720.0              3 years        0.0
# 2468  Home Mortgage      5589420.0              4 years        0.0
# 837   Home Mortgage      5131482.0              2 years        0.0
# 7486           Rent      5327372.0               1 year        0.0
# 1616  Home Mortgage      7907382.0            10+ years        1.0
# 4685  Home Mortgage      6961752.0              3 years        0.0
# 4271  Home Mortgage      5798040.0             < 1 year        2.0
# 5365  Home Mortgage      5038534.0               1 year        0.0
# 2169           Rent      5584271.0              4 years        0.0
# 1025           Rent      8923844.0              3 years        0.0
#
#       Number of Open Accounts  Years of Credit History  Maximum Open Credit  \
# 5774                     12.0                     10.8            1837616.0
# 4491                     11.0                     16.7             333630.0
# 7089                     27.0                     27.2            3930212.0
# 3446                     13.0                     37.6            1387320.0
# 602                       5.0                     17.5                  0.0
# 3269                      6.0                     13.6             424864.0
# 4745                     30.0                     17.5           11603856.0
# 6946                     19.0                     26.0            1406526.0
# 7299                     17.0                     15.4             437492.0
# 4445                      7.0                     25.4             846516.0
# 2992                     11.0                     28.9            1107634.0
0
#
#       Number of Credit Problems  Months since last delinquent  Bankruptcies  \
# 2689                        0.0                           NaN           0.0
# 305                         0.0                          75.0           0.0
# 6868                        1.0                           NaN           0.0
# 3874                        0.0                          66.0           0.0
# 6842                        0.0                           NaN           0.0
# 1950                        0.0                           NaN           0.0
# 423                         0.0                           NaN           0.0
# 5261                        0.0                          79.0           0.0
# 5037                        0.0                           NaN           0.0
# 3421                        1.0                          18.0           1.0
# 5526                        0.0                          14.0           0.0
# 3475                        0.0                           NaN           0.0
# 4046                        0.0                           NaN           0.0
# 5091                        0.0                           NaN           0.0
# 2181                        1.0                          68.0           1.0
# 5382                        0.0                           NaN           0.0
# 5738                        0.0                           NaN           0.0
# 4254                        0.0                           NaN           0.0
# 2840                        0.0                           NaN           0.0
# 1374                        0.0                          14.0           0.0
# 4484                        0.0                           NaN           0.0
# 464                         0.0                           NaN           0.0
#
#                  Purpose        Term  Current Loan Amount  \
# 2689               other  Short Term             105600.0
# 305                other  Short Term              75262.0
# 6868  debt consolidation   Long Term             247170.0
# 3874  debt consolidation  Short Term           99999999.0
# 6842  debt consolidation  Short Term             239470.0
# 1950  debt consolidation   Long Term             694012.0
# 423    home improvements  Short Term             259072.0
# 5261  debt consolidation  Short Term             337898.0
# 5037  debt consolidation   Long Term             537196.0
# 3421               other  Short Term           99999999.0
# 5526  debt consolidation  Short Term             636746.0
# 3475      small business  Short Term             134376.0
# 4046  debt consolidation  Short Term             423588.0
# 5091  debt consolidation   Long Term             311960.0
# 2181  debt consolidation  Short Term             531168.0
# 5382  debt consolidation   Long Term             425414.0
# 5738  debt consolidation  Short Term             777238.0
# 4254  debt consolidation   Long Term             530684.0
# 2840  debt consolidation  Short Term             448976.0
# 1374  debt consolidation   Long Term             437448.0
# 4484  debt consolidation  Short Term             550044.0
# 464   debt consolidation  Short Term             333014.0
#
#       Current Credit Balance  Monthly Debt  Credit Score  Credit Default
# 2689                 57589.0       30297.0           NaN               0
# 305                  47424.0        1870.0           NaN               0
# 6868                535895.0       37611.0         731.0               0
# 3874                652308.0       15204.0         742.0               0
# 6842                363071.0       16817.0         694.0               1
# 1950                695457.0       36888.0         734.0               1
# 423                  31882.0       10164.0         750.0               0
# 5261                639635.0       65025.0         732.0               0
# 5037                872024.0       29599.0         685.0               0
# 3421                 93214.0       11789.0         733.0               0
# 5526                154584.0       38267.0         743.0               0
# 3475                113278.0        3984.0         589.0               1
# 4046                652954.0       25492.0           NaN               0
# 5091                362159.0       12374.0        7140.0               1
# 2181                198911.0       54833.0         746.0               0
# 5382                467590.0       19669.0        6950.0               1
# 5738               1388178.0       62487.0        6800.0               1
# 4254                792946.0       61182.0         733.0               1
# 2840                637184.0       43880.0         720.0               0
# 1374                504222.0       20070.0         721.0               1
# 4484                623523.0       33854.0         651.0               1
# 464                 772559.0       22744.0         748.0               0

# %% [markdown]
# Значение **'Number of Open Accounts' > 30** явно является выбросом. Заменим его на медианное значение.

# %%
median_accounts = train['Number of Open Accounts'].median()

# %%
train.loc[train['Years of Credit History'] > 45, :]
# Out:
#      Home Ownership  Annual Income Years in current job  Tax Liens  \
#
0.0
#
#                  Purpose        Term  Current Loan Amount  \
# 4716  debt consolidation   Long Term             614614.0
# 5636   home improvements  Short Term             562430.0
# 6241  debt consolidation   Long Term             703076.0
# 476   debt consolidation   Long Term             558360.0
# 3165  debt consolidation  Short Term             786478.0
# 3628  debt consolidation  Short Term              78980.0
# 3538               other  Short Term             142714.0
# 710   debt consolidation  Short Term             102410.0
# 5673  debt consolidation   Long Term             439912.0
# 6507  debt consolidation  Short Term           99999999.0
# 4171           buy a car  Short Term              77330.0
# 4464               other   Long Term             559086.0
# 2011  debt consolidation  Short Term             152020.0
# 7366               other  Short Term             126610.0
# 5024  debt consolidation  Short Term             180378.0
# 5460               other  Short Term             224972.0
# 3091  debt consolidation  Short Term           99999999.0
# 881   debt consolidation  Short Term             479512.0
# 4301   home improvements  Short Term             108152.0
# 7251  debt consolidation   Long Term             439252.0
# 247   debt consolidation   Long Term             429880.0
# 793   debt consolidation  Short Term             152394.0
#
#       Current Credit Balance  Monthly Debt  Credit Score  Credit Default
# 4716                416518.0       16541.0           NaN               1
# 5636                193173.0       26813.0         749.0               0
# 6241                585789.0       19108.0           NaN               0
# 476                 186219.0       13818.0         667.0               1
# 3165                721240.0       40544.0         680.0               0
# 3628                 99712.0        9972.0         720.0               0
# 3538                 61180.0        2753.0        7460.0               1
# 710                  85576.0        4974.0           NaN               1
# 5673                486267.0       15514.0         727.0               0
# 6507                280801.0        8122.0         728.0               0
# 4171                638362.0       19442.0         750.0               0
# 4464                107730.0        6845.0         709.0               0
# 2011                496717.0        9452.0         751.0               0
# 7366                 73321.0        3743.0         726.0               0
# 5024                263986.0       22345.0         721.0               0
# 5460                158517.0       12678.0         721.0               0
# 3091                228190.0        7180.0         750.0               0
# 881                 534071.0       15776.0         720.0               0
# 4301                384750.0       28280.0           NaN               0
# 7251               1369577.0       22516.0           NaN               1
# 247                 500802.0       41024.0         654.0               1
# 793                  81244.0       19426.0           NaN               1

# %% [markdown]
# Значение **'Years of Credit History' > 45** явно является выбросом. Заменим его на медианное значение.

# %%
median_years_history = train['Years of Credit History'].median()

# %%
train.loc[train['Maximum Open Credit'] > 10**7, :]
# Out:
#      Home Ownership  Annual Income Years in current job  Tax Liens  \
# 4840  Home Mortgage      1687599.0              5 years        0.0
# 2617  Home Mortgage      3217802.0            10+ years        0.0
# 4745       Own Home      6029954.0              4 years        0.0
# 44    Have Mortgage      1334256.0            10+ years        0.0
# 5523  Home Mortgage      1520304.0            10+ years        0.0
# 2023           Rent      1342825.0            10+ years        0.0
# 5950  Home Mortgage      1921660.0            10+ years        0.0
# 617   Home Mortgage            NaN              3 years        0.0
# 5731  Home Mortgage      1475198.0              8 years        0.0
# 2468  Home Mortgage      5589420.0              4 years        0.0
# 4769  Home Mortgage      3739960.0              9 years        0.0
# 354   Home Mortgage      2126537.0            10+ years        0.0
#
#       Number of Open Accounts  Years of Credit History  Maximum Open Credit  \
# 4840                     17.0                     17.1         1.020160e+07
# 2617                     12.0                     35.5         2.655129e+08
# 4745                     30.0                     17.5         1.160386e+07
# 44                       17.0                     15.4         3.800523e+08
# 5523                     21.0                     35.5         2.137243e+07
# 2023                     12.0                     16.3         5.756256e+07
# 5950                     13.0                     21.0         1.151346e+07
# 617                      13.0                     27.5         1.304726e+09
# 5731                     10.0                     24.9         1.928043e+07
# 2468                     11.0                     12.3         1.634591e+07
# 4769                      7.0                     22.8         2.634333e+07
# 354                      23.0                     23.0         1.476048e+07
#
#       Number of Credit Problems  Months since last delinquent  Bankruptcies  \
# 4840                        0.0                          21.0           0.0
# 2617                        0.0                           NaN           0.0
# 4745                        0.0                           NaN           0.0
# 44                          1.0                          35.0           0.0
# 5523                        0.0                           0.0           0.0
# 2023                        0.0                           NaN           0.0
# 5950                        0.0                           NaN           0.0
# 617                         0.0                           NaN           0.0
# 5731                        0.0                           NaN           0.0
# 2468                        0.0                          24.0           0.0
# 4769                        0.0                           NaN           0.0
# 354                         0.0                           NaN           0.0
#
#                  Purpose        Term  Current Loan Amount  \
# 4840  debt consolidation  Short Term           99999999.0
# 2617               other  Short Term              50116.0
# 4745  debt consolidation  Short Term             753588.0
# 44           take a trip  Short Term              33110.0
# 5523               other   Long Term           99999999.0
# 2023               other  Short Term             166826.0
# 5950   home improvements   Long Term             267014.0
# 617   debt consolidation  Short Term             529892.0
# 5731  debt consolidation  Short Term           99999999.0
# 2468   home improvements   Long Term           99999999.0
# 4769   home improvements  Short Term             757834.0
# 354   debt consolidation   Long Term             778624.0
#
#       Current Credit Balance  Monthly Debt  Credit Score  Credit Default
# 4840               2784108.0       26298.0         735.0               0
# 2617               1834450.0       20272.0         750.0               0
# 4745               4720132.0      136679.0         745.0               0
# 44                  656450.0       34357.0         729.0               0
# 5523               1975012.0       12555.0         728.0               0
# 2023                944547.0        9176.0         749.0               0
# 5950                835259.0       32636.0         738.0               0
# 617                1126814.0        5492.0           NaN               0
# 5731               1132286.0       17543.0         751.0               0
# 2468               2315169.0       74991.0         735.0               0
# 4769               6506797.0       38023.0         703.0               0
# 354                1019806.0       40227.0         697.0               0

# %% [markdown]
# Значение **'Maximum Open Credit' > 2*10^7** явно является выбросом. Заменим его на медианное значение.

# %%
median_max_credit = train['Maximum Open Credit'].median()

# %%
train.loc[train['Months since last delinquent'] > 100, :]
# Out:
#      Home Ownership  Annual Income Years in current job  Tax Liens  \
# 4191  Home Mortgage      3009201.0              6 years        0.0
#
#       Number of Open Accounts  Years of Credit History  Maximum Open Credit  \
# 4191                     10.0                     20.8             773322.0
#
#       Number of Credit Problems  Months since last delinquent  Bankruptcies  \
# 4191                        0.0                         118.0           0.0
#
#                  Purpose        Term  Current Loan Amount  \
# 4191  debt consolidation  Short Term             449592.0
#
#       Current Credit Balance  Monthly Debt  Credit Score  Credit Default
# 4191                299877.0       15297.0         738.0               0

# %% [markdown]
# Значение **'Months since last delinquent' > 100** явно является выбросом. Заменим его на медианное значение.

# %%
median_months_delinquent = train['Months since last delinquent'].median()

# %%
train.loc[train['Current Credit Balance'] > 3*10**6, :]
# Out:
#      Home Ownership  Annual Income Years in current job  Tax Liens  \
# 162   Home Mortgage      2131591.0             < 1 year        0.0
# 4745       Own Home      6029954.0              4 years        0.0
# 2618  Home Mortgage      3199448.0            10+ years        0.0
# 3198  Home Mortgage            NaN            10+ years        0.0
# 3316  Home Mortgage            NaN              9 years        0.0
# 4602  Home Mortgage      3990038.0            10+ years        0.0
# 1931  Home Mortgage      2773468.0            10+ years        0.0
# 4769  Home Mortgage      3739960.0              9 years        0.0
#
#       Number of Open Accounts  Years of Credit History  Maximum Open Credit  \
# 162                      15.0                     31.7            4191176.0
# 4745                     30.0                     17.5           11603856.0
# 2618                     11.0                     26.3            5109676.0
# 3198                     14.0                     26.9            5150860.0
# 3316                     17.0                     28.4            6619316.0
# 4602                     10.0                     23.0            9541136.0
# 1931                      8.0                     29.0            3979206.0
# 4769                      7.0                     22.8           26343328.0
#
#       Number of Credit Problems  Months since last delinquent  Bankruptcies  \
# 162                         0.0                           NaN           0.0
# 4745                        0.0                           NaN           0.0
# 2618                        0.0                          71.0           0.0
# 3198                        0.0                          49.0           0.0
# 3316                        0.0                           NaN           0.0
# 4602                        0.0                           5.0           0.0
# 1931                        0.0                          12.0           0.0
# 4769                        0.0                           NaN           0.0
#
#                  Purpose        Term  Current Loan Amount  \
# 162   debt consolidation  Short Term             269258.0
# 4745  debt consolidation  Short Term             753588.0
# 2618  debt consolidation  Short Term             767228.0
# 3198   home improvements  Short Term             163680.0
# 3316  debt consolidation   Long Term             522874.0
# 4602   home improvements   Long Term             788788.0
# 1931  debt consolidation  Short Term           99999999.0
# 4769   home improvements  Short Term             757834.0
#
#       Current Credit Balance  Monthly Debt  Credit Score  Credit Default
#
0
#
#       Number of Credit Problems  Months since last delinquent  Bankruptcies  \
# 7459                        3.0                          37.0           0.0
# 1472                        0.0                           1.0           0.0
# 7478                        0.0                          21.0           0.0
# 2535                        0.0                           NaN           0.0
# 4745                        0.0                           NaN           0.0
# 280                         0.0                           NaN           0.0
# 6946                        0.0                           NaN           0.0
# 5102                        0.0                           3.0           0.0
# 7179                        0.0                           NaN           0.0
# 3198                        0.0                          49.0           0.0
# 3453                        0.0                          22.0           0.0
# 6253                        0.0                          14.0           0.0
# 974                         0.0                           NaN           0.0
# 6486                        0.0                           NaN           0.0
# 2502                        0.0                           NaN           0.0
# 6990                        0.0                           NaN           0.0
# 2468                        0.0                          24.0           0.0
# 3601                        1.0                          21.0           0.0
# 5542                        0.0                          23.0           0.0
# 2853                        0.0                          25.0           0.0
# 5618                        0.0                          48.0           0.0
# 4439                        0.0                          23.0           0.0
# 6727                        0.0                           NaN           0.0
#
#                  Purpose        Term  Current Loan Amount  \
# 7459  debt consolidation  Short Term             458854.0
# 1472  debt consolidation  Short Term             616792.0
# 7478  debt consolidation  Short Term             787864.0
# 2535  debt consolidation   Long Term             542146.0
# 4745  debt consolidation  Short Term             753588.0
# 280    home improvements  Short Term             784322.0
# 6946               other  Short Term             322190.0
# 5102  debt consolidation  Short Term             773784.0
# 7179  debt consolidation  Short Term             429572.0
# 3198   home improvements  Short Term             163680.0
# 3453               other  Short Term           99999999.0
# 6253  debt consolidation  Short Term             570262.0
# 974   debt consolidation  Short Term           99999999.0
# 6486  debt consolidation   Long Term             301048.0
# 2502  debt consolidation  Short Term           99999999.0
# 6990   home improvements   Long Term             570284.0
# 2468   home improvements   Long Term           99999999.0
# 3601  debt consolidation  Short Term             306284.0
# 5542  debt consolidation   Long Term           99999999.0
# 2853       business loan  Short Term             767932.0
# 5618  debt consolidation  Short Term             516934.0
# 4439       business loan  Short Term             537086.0
# 6727  debt consolidation   Long Term             631268.0
#
#       Current Credit Balance  Monthly Debt  Credit Score  Credit Default
# 7459               1149614.0       85030.0           NaN               0
# 1472                534356.0       84359.0         742.0               1
# 7478                402914.0       93640.0         703.0               0
# 2535               2889577.0      104036.0         656.0               1
# 4745               4720132.0      136679.0         745.0               0
# 280                 518738.0       95508.0           NaN               1
# 6946               1169773.0      100091.0         707.0               0
# 5102                136629.0       79555.0         709.0               0
# 7179                277191.0       83783.0         748.0               1
# 3198               3683340.0       75910.0           NaN               0
# 3453                584630.0       72996.0         723.0               0
# 6253                589855.0       96177.0           NaN               0
# 974                1685585.0       81346.0         747.0               0
# 6486                621946.0       78925.0         729.0               1
# 2502                718618.0       87994.0         729.0               0
# 6990                392806.0       79661.0         737.0               0
# 2468               2315169.0       74991.0         735.0               0
# 3601               2059942.0       84738.0         740.0               0
# 5542               2194310.0       70961.0         602.0               0
# 2853                674120.0       70268.0         680.0               0
# 5618               1221339.0       73412.0        7460.0               1
# 4439                493753.0       89789.0         690.0               1
# 6727                771533.0       83158.0         734.0               1

# %% [markdown]
# Значение **'Monthly Debt' > 70 000** явно является выбросом. Заменим его на медианное значение.

# %%
median_monthly_debt = train['Monthly Debt'].median()

# %%
plt.figure(figsize=(20,20))

sns.set(font_scale=1.4)
sns.heatmap(train[not_obj_col].corr().round(3),annot=True, linewidths=0.5, cmap='GnBu')

# %%
null_credit_score = train[train['Credit Score'].isnull()].index
not_null__credit_score = train[train['Credit Score'].notnull()].index

# %%
null_credit_score
# Out:
# Int64Index([4716,  532, 2140, 1393,  481, 1499, 4521, 2351, 5176, 2301,
#             ...
#             6418, 1765, 6266, 1789,  829,  447, 6655,   48,  772, 7113],
#            dtype='int64', length=1186)

# %%
not_null__credit_score
# Out:
# Int64Index([4864, 7199, 2560, 3474, 4290, 7465,  533, 6748, 3725, 5006,
#             ...
#             1646,  840, 4298, 6897, 4706, 6844, 1144, 6512, 5944, 5327],
#            dtype='int64', length=4439)

# %%
y_train_credit = train.loc[not_null__credit_score, :]
y_train_credit = y_train_credit['Credit Score']
X_train_credit = train.loc[not_null__credit_score, :]
X_train_credit = X_train_credit.drop('Credit Score', axis=1)
X_train_credit = X_train_credit[['Bankruptcies', 'Number of Credit Problems', 'Maximum Open Credit', 'Years of Credit History', 'Number of Open Accounts']]

# %%
X_test_credit = train.loc[null_credit_score, :]
X_test_credit = X_test_credit.drop('Credit Score', axis=1)
X_test_credit = X_test_credit[['Bankruptcies', 'Number of Credit Problems', 'Maximum Open Credit', 'Years of Credit History', 'Number of Open Accounts']]

# %%
parameters = {'n_estimators': [150, 200, 250],
              'max_features': np.arange(3, 6),
              'max_depth': np.arange(7, 10)}

clf_credit = GridSearchCV(estimator=RandomForestRegressor(random_state=42),
                   param_grid=parameters,
                   scoring='r2',
                   cv=4)

# %%
clf_credit.fit(X_train_credit, y_train_credit)
# Out:
# GridSearchCV(cv=4, error_score='raise-deprecating',
#        estimator=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#            oob_score=False, random_state=42, verbose=0, warm_start=False),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'n_estimators': [150, 200, 250], 'max_features': array([3, 4, 5]), 'max_depth': array([7, 8, 9])},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='r2', verbose=0)

# %%
clf_credit.best_params_
# Out:
# {'max_depth': 7, 'max_features': 3, 'n_estimators': 250}

# %%
clf_credit = RandomForestRegressor(max_depth=7, max_features=3, n_estimators=250)
clf_credit.fit(X_train_credit, y_train_credit)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=7,
#            max_features=3, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=250, n_jobs=None, oob_score=False,
#            random_state=None, verbose=0, warm_start=False)

# %%
y_test_credit = clf_credit.predict(X_test_credit)
y_test_credit
# Out:
# array([1099.22811156, 2064.87479265, 1352.1355067 , ..., 1190.15357878,
#        1222.94602287, 1207.54409961])

# %%
train.loc[null_credit_score, 'Credit Score'] = y_test_credit
# Out:
# D:\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %% [markdown]
# Применение функции по изменению данных. Тренировочная выборка.

# %%
modify_data(train, median_annual_income, median_accounts, median_months_delinquent, median_years_history, median_max_credit, 
            median_current_credit_balance, median_monthly_debt, median_bankruptcies)
# Out:
# D:\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]

# %%
train.describe()
# Out:
#        Annual Income    Tax Liens  Number of Open Accounts  \
# count   4.439000e+03  5625.000000              5625.000000
# mean    1.327452e+06     0.030044                11.058667
# std     7.011857e+05     0.264657                 4.722654
# min     1.645970e+05     0.000000                 2.000000
# 25%     8.401325e+05     0.000000                 8.000000
# 50%     1.171920e+06     0.000000                10.000000
# 75%     1.626932e+06     0.000000                14.000000
# max     4.906028e+06     6.000000                30.000000
#
#        Years of Credit History  Maximum Open Credit  \
# count              5625.000000         5.625000e+03
# mean                 18.211200         6.431799e+05
# std                   6.821262         6.720867e+05
# min                   4.000000         0.000000e+00
# 25%                  13.500000         2.801700e+05
# 50%                  17.000000         4.819100e+05
# 75%                  21.700000         7.905480e+05
# max                  44.800000         9.541136e+06
#
#        Number of Credit Problems  Months since last delinquent  Bankruptcies  \
# count                5625.000000                   2569.000000   5625.000000
# mean                    0.166044                     34.626703      0.112889
# std                     0.488654                     21.560382      0.336103
# min                     0.000000                      0.000000      0.000000
# 25%                     0.000000                     16.000000      0.000000
# 50%                     0.000000                     32.000000      0.000000
# 75%                     0.000000                     50.000000      0.000000
# max                     6.000000                     92.000000      4.000000
#
#        Current Loan Amount  Current Credit Balance  Monthly Debt  \
# count         5.625000e+03            5.625000e+03   5625.000000
# mean          1.177759e+07            2.836054e+05  18074.886044
# std           3.180890e+07            2.779822e+05  11184.390413
# min           2.147200e+04            0.000000e+00      0.000000
# 25%           1.814340e+05            1.140950e+05  10039.000000
# 50%           3.111020e+05            2.092850e+05  16087.000000
# 75%           5.265700e+05            3.587390e+05  23716.000000
# max           1.000000e+08            2.913707e+06  69413.000000
#
#        Credit Score  Credit Default   Short Term
# count   5625.000000     5625.000000  5625.000000
# mean    1150.768600        0.280711     0.740622
# std     1432.093191        0.449387     0.438332
# min      585.000000        0.000000     0.000000
# 25%      718.000000        0.000000     0.000000
# 50%      738.000000        0.000000     1.000000
# 75%      915.004056        1.000000     1.000000
# max     7510.000000        1.000000     1.000000

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5625 entries, 4864 to 7113
# Data columns (total 18 columns):
# Home Ownership                  5625 non-null object
# Annual Income                   4439 non-null float64
# Years in current job            5348 non-null object
# Tax Liens                       5625 non-null float64
# Number of Open Accounts         5625 non-null float64
# Years of Credit History         5625 non-null float64
# Maximum Open Credit             5625 non-null float64
# Number of Credit Problems       5625 non-null float64
# Months since last delinquent    2569 non-null float64
# Bankruptcies                    5625 non-null float64
# Purpose                         5625 non-null object
# Term                            5625 non-null object
# Current Loan Amount             5625 non-null float64
# Current Credit Balance          5625 non-null float64
# Monthly Debt                    5625 non-null float64
# Credit Score                    5625 non-null float64
# Credit Default                  5625 non-null int64
# Short Term                      5625 non-null int32
# dtypes: float64(12), int32(1), int64(1), object(4)
# memory usage: 973.0+ KB

# %%
train.columns
# Out:
# Index(['Home Ownership', 'Annual Income', 'Years in current job', 'Tax Liens',
#        'Number of Open Accounts', 'Years of Credit History',
#        'Maximum Open Credit', 'Number of Credit Problems',
#        'Months since last delinquent', 'Bankruptcies', 'Purpose', 'Term',
#        'Current Loan Amount', 'Current Credit Balance', 'Monthly Debt',
#        'Credit Score', 'Credit Default', 'Short Term'],
#       dtype='object')

# %%
features = ['Number of Open Accounts', 'Years of Credit History',
            'Maximum Open Credit', 'Number of Credit Problems', 'Bankruptcies',
            'Current Loan Amount', 'Current Credit Balance', 'Monthly Debt',
            'Short Term', 'Credit Score']

# %%
train_balanced = get_balance(train, 'Credit Default')
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning:
# The current behaviour of 'Series.argmax' is deprecated, use 'idxmax'
# instead.
# The behavior of 'argmax' will be corrected to return the positional
# maximum in the future. For now, use 'series.values.argmax' or
# 'np.argmax(np.array(values))' to get the position of the maximum
# row.
#   """
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning:
# The current behaviour of 'Series.argmin' is deprecated, use 'idxmin'
# instead.
# The behavior of 'argmin' will be corrected to return the positional
# minimum in the future. For now, use 'series.values.argmin' or
# 'np.argmin(np.array(values))' to get the position of the minimum
# row.

# %%
train_balanced['Credit Default'].value_counts()
# Out:
# 0    4046
# 1    3158
# Name: Credit Default, dtype: int64

# %%
y_train = train_balanced['Credit Default']
X_train = train_balanced[features]

# %%
scaler = MinMaxScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train), columns=features)
# Out:
# D:\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:334: DataConversionWarning: Data with input dtype int32, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)

# %%
X_train.describe()
# Out:
#        Number of Open Accounts  Years of Credit History  Maximum Open Credit  \
# count              7204.000000              7204.000000          7204.000000
# mean                  0.325365                 0.346616             0.065844
# std                   0.169304                 0.167980             0.067598
# min                   0.000000                 0.000000             0.000000
# 25%                   0.214286                 0.232843             0.028714
# 50%                   0.285714                 0.318627             0.049544
# 75%                   0.428571                 0.431373             0.081345
# max                   1.000000                 1.000000             1.000000
#
#        Number of Credit Problems  Bankruptcies  Current Loan Amount  \
# count                7204.000000   7204.000000          7204.000000
# mean                    0.028410      0.028352             0.092488
# std                     0.083285      0.084163             0.285095
# min                     0.000000      0.000000             0.000000
# 25%                     0.000000      0.000000             0.001606
# 50%                     0.000000      0.000000             0.002874
# 75%                     0.000000      0.000000             0.004760
# max                     1.000000      1.000000             1.000000
#
#        Current Credit Balance  Monthly Debt   Short Term  Credit Score
# count             7204.000000   7204.000000  7204.000000   7204.000000
# mean                 0.097027      0.261807     0.712937      0.109989
# std                  0.093905      0.161241     0.452423      0.253341
# min                  0.000000      0.000000     0.000000      0.000000
# 25%                  0.039122      0.146385     0.000000      0.019206
# 50%                  0.071828      0.231758     1.000000      0.022238
# 75%                  0.123154      0.343452     1.000000      0.064184
# max                  1.000000      1.000000     1.000000      1.000000

# %%
X_train = X_train[features]

# %%
parameters = {'n_estimators': [150, 200, 250],
              'max_features': np.arange(8, 11),
              'max_depth': np.arange(7, 10)}

clf = GridSearchCV(estimator=RandomForestClassifier(random_state=42),
                   param_grid=parameters,
                   scoring='f1',
                   cv=4)

# %%
clf.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=4, error_score='raise-deprecating',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#             oob_score=False, random_state=42, verbose=0, warm_start=False),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'n_estimators': [150, 200, 250], 'max_features': array([ 8,  9, 10]), 'max_depth': array([7, 8, 9])},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='f1', verbose=0)

# %%
clf.best_params_
# Out:
# {'max_depth': 9, 'max_features': 9, 'n_estimators': 200}

# %%
res = pd.DataFrame(clf.cv_results_)

res.columns

# %%
clf_rf = RandomForestClassifier(max_depth=9, max_features=9, n_estimators=200)
clf_rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=9, max_features=9, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=200, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
y_train_pred = clf_rf.predict(X_train)

# %%
cat = catb.CatBoostClassifier(silent=True, random_state=42)
cat.fit(X_train, y_train)

# %%
y_train_pred = cat.predict(X_train)

# %%
sns.barplot(cat.feature_importances_, X_train.columns)

# %% [markdown]
# Применение функции по изменению данных. Валидационная выборка.

# %%
modify_data(valid, median_annual_income, median_accounts, median_months_delinquent, median_years_history, median_max_credit, 
            median_current_credit_balance, median_monthly_debt, median_bankruptcies)
# Out:
# D:\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]

# %%
null_credit_score = valid[valid['Credit Score'].isnull()].index
not_null__credit_score = valid[valid['Credit Score'].notnull()].index

# %%
null_credit_score
# Out:
# Int64Index([6079, 3858, 1386, 5290, 5098, 3900, 7073,  512, 6214, 7442,
#             ...
#             3482,  817, 3712,  722, 6761, 3214, 6369, 1139, 5918, 1271],
#            dtype='int64', length=371)

# %%
not_null__credit_score
# Out:
# Int64Index([6322, 5231, 5360, 3518,  921, 1315, 3123, 7097, 5846, 2596,
#             ...
#             2430, 3045, 5125, 7438, 2716, 2658, 4259, 1909, 1001, 6992],
#            dtype='int64', length=1504)

# %%
X_test_credit = valid.loc[null_credit_score, :]
X_test_credit = X_test_credit.drop('Credit Score', axis=1)
X_test_credit = X_test_credit[['Bankruptcies', 'Number of Credit Problems', 'Maximum Open Credit', 'Years of Credit History', 'Number of Open Accounts']]

# %%
y_test_credit = clf_credit.predict(X_test_credit)
y_test_credit
# Out:
# array([1082.09511602, 1344.60273677,  850.26737049, 1154.633579  ,
#        1193.03012224, 1038.20061408, 1239.6987032 ,  985.26162013,
#        1249.61193618, 1395.81820116, 1202.19033911, 1755.9481955 ,
#         928.27682958, 1617.08608357, 1110.25565326, 2225.41348294,
#        1114.89044633, 1242.90888017, 1188.49239048,  905.04581468,
#        1185.25917092, 1311.11265251, 1171.82287769,  843.52519567,
#        1086.8957314 ,  933.89662003,  945.59950618, 1294.97963832,
#        2029.98604527, 1233.94784499, 1011.56532266, 1113.62832732,
#        1689.39400548, 1279.59266512, 1395.61940044, 1115.17194321,
#         956.52296877, 1110.1819466 ,  943.41843931, 2459.96266135,
#        1146.67967953, 1212.77782378,  962.59685088, 1242.03760575,
#        1086.36615411, 1084.79329063, 1046.29010299, 1462.64997224,
#        1231.56070234, 1171.11063699,  928.95123483, 1032.61064007,
#        1065.01570567, 1137.68126908, 1158.33156102, 1143.25863276,
#        1266.31964408, 1145.69908148,  955.09390067, 1650.68548316,
#        1386.54846481, 1192.67957749, 1213.50877027, 1233.75240348,
#        1217.38684195, 1010.46121601,  977.5807906 , 1266.74355109,
#        1139.10355843, 1260.63284096, 1038.04667016, 1249.79258852,
#        1047.08695128, 1138.68490132, 1099.51474564, 1283.50587256,
#         955.31209918, 1090.79939572,  972.66923283,  986.6317112 ,
#        1146.99768564, 1235.13872585, 1023.59327173, 1032.88224284,
#        1149.25185057, 1243.18077599, 1124.82896496, 1308.39286334,
#        1443.58011198, 1230.89341744, 1281.64680222, 1158.0747821 ,
#        1087.95203653, 1195.00866515, 1151.53746627, 1011.51174711,
#        1442.179329  , 1088.487221  ,  888.97618211,  989.11862928,
#        1285.84907242, 1172.39278829, 1189.97047466, 1173.47155314,
#        1113.23518881, 1100.2749122 , 1140.86582778, 1196.3938299 ,
#         898.32111809,  959.52273233, 1076.30984045, 1158.59148731,
#        1280.7603997 , 1170.46463741,  898.9585077 , 1105.23214256,
#        1227.41042071,  971.92879571,  994.40543759, 1074.1330095 ,
#         948.59258863, 1112.39556425,  985.33424972, 1275.44467902,
#        1203.55874837,  975.65383748, 1080.7156131 , 1144.906573  ,
#         896.18584197, 1199.1343177 ,  973.79031215,  890.59498339,
#        1240.61648191, 1235.84404393, 1400.64002019,  950.94466409,
#        1323.18709014, 1181.73783469, 1156.80292759, 1087.74738922,
#        1140.32468042, 1533.98758344, 1322.70132909, 1178.40043326,
#         831.47071222,  922.32550574, 1180.56731909,  939.0345506 ,
#        1304.99953669, 1098.79511535, 1154.71055258, 1160.46329495,
#        1141.39944145, 1272.99925935,  948.55428164, 1199.69700622,
#         852.35547722, 1215.89503173, 1354.78420233, 1051.81461129,
#        1223.18488326,  979.42670367, 1201.39709172, 2069.6692569 ,
#        1181.90137074, 1156.40324646, 1122.64786746, 1122.55507382,
#        1196.18184971, 1159.51946421, 1134.88601634,  916.33384895,
#        1248.30037856, 1078.1354328 , 1193.13542869, 1152.11864796,
#        1146.3461424 ,  968.09074658, 1033.06834295,  928.32394471,
#         971.13395117,  842.73013692, 1173.72279762, 1130.06133825,
#        1261.15965712,  909.80014905,  996.00676615])

# %%
valid.loc[null_credit_score, 'Credit Score'] = y_test_credit
# Out:
# D:\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
y_valid = valid['Credit Default']
X_valid = valid[features]

# %%
X_valid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1875 entries, 6079 to 6992
# Data columns (total 10 columns):
# Number of Open Accounts      1875 non-null float64
# Years of Credit History      1875 non-null float64
# Maximum Open Credit          1875 non-null float64
# Number of Credit Problems    1875 non-null float64
# Bankruptcies                 1875 non-null float64
# Current Loan Amount          1875 non-null float64
# Current Credit Balance       1875 non-null float64
# Monthly Debt                 1875 non-null float64
# Short Term                   1875 non-null int32
# Credit Score                 1875 non-null float64
# dtypes: float64(9), int32(1)
# memory usage: 233.8 KB

# %%
valid['Credit Default'].value_counts()
# Out:
# 0    1341
# 1     534
# Name: Credit Default, dtype: int64

# %%
X_valid.describe()
# Out:
#        Number of Open Accounts  Years of Credit History  Maximum Open Credit  \
# count              1875.000000              1875.000000         1.875000e+03
# mean                 11.002667                18.182240         6.438912e+05
# std                   4.669378                 6.745487         6.812635e+05
# min                   2.000000                 5.000000         0.000000e+00
# 25%                   8.000000                13.500000         2.766940e+05
# 50%                  10.000000                17.000000         4.711300e+05
# 75%                  14.000000                21.900000         7.888540e+05
# max                  30.000000                44.700000         9.339924e+06
#
#        Number of Credit Problems  Bankruptcies  Current Loan Amount  \
# count                1875.000000   1875.000000         1.875000e+03
# mean                    0.181867      0.129067         1.215993e+07
# std                     0.527263      0.377294         3.228209e+07
# min                     0.000000      0.000000         1.124200e+04
# 25%                     0.000000      0.000000         1.783320e+05
# 50%                     0.000000      0.000000         3.021480e+05
# 75%                     0.000000      0.000000         4.986630e+05
# max                     7.000000      4.000000         1.000000e+08
#
#        Current Credit Balance  Monthly Debt   Short Term  Credit Score
# count            1.875000e+03   1875.000000  1875.000000   1875.000000
# mean             2.870049e+05  17923.126400     0.741333   1145.051240
# std              2.916500e+05  10873.679247     0.438019   1426.423951
# min              0.000000e+00      0.000000     0.000000    588.000000
# 25%              1.151210e+05  10198.500000     0.000000    718.000000
# 50%              2.095130e+05  15960.000000     1.000000    738.000000
# 75%              3.577795e+05  23419.000000     1.000000    829.295818
# max              2.759503e+06  65167.000000     1.000000   7510.000000

# %%
X_valid = pd.DataFrame(scaler.transform(X_valid), columns=features)

# %%
y_valid_pred = clf_rf.predict(X_valid)
pd.DataFrame(y_valid_pred)[0].value_counts()
# Out:
# 0    1428
# 1     447
# Name: 0, dtype: int64

# %%
get_classification_report(y_train, y_train_pred, y_valid, y_valid_pred)
# Out:
# TRAIN
#
#               precision    recall  f1-score   support
#
#            0       0.77      0.92      0.84      4046
#            1       0.87      0.64      0.74      3158
#
#    micro avg       0.80      0.80      0.80      7204
#    macro avg       0.82      0.78      0.79      7204
# weighted avg       0.81      0.80      0.80      7204
#
# TEST
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.85      0.83      1341
#            1       0.56      0.47      0.51       534
#
#    micro avg       0.75      0.75      0.75      1875
#    macro avg       0.68      0.66      0.67      1875
# weighted avg       0.73      0.75      0.74      1875
#
# CONFUSION MATRIX
#
# col_0              0    1
# Credit Default
# 0               1146  195
# 1                282  252

# %%
y_valid_pred = cat.predict(X_valid)
pd.DataFrame(y_valid_pred)[0].value_counts()
# Out:
# 0    1439
# 1     436
# Name: 0, dtype: int64

# %%
y_train_pred_proba = cat.predict_proba(X_valid)
y_train_pred_proba
# Out:
# array([[0.64911067, 0.35088933],
#        [0.43783283, 0.56216717],
#        [0.53710629, 0.46289371],
#        ...,
#        [0.59512138, 0.40487862],
#        [0.75309237, 0.24690763],
#        [0.66449227, 0.33550773]])

# %%
get_classification_report(y_train, y_train_pred, y_valid, y_valid_pred)
# Out:
# TRAIN
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.95      0.90      4046
#            1       0.93      0.80      0.86      3158
#
#    micro avg       0.89      0.89      0.89      7204
#    macro avg       0.90      0.88      0.88      7204
# weighted avg       0.89      0.89      0.89      7204
#
# TEST
#
#               precision    recall  f1-score   support
#
#            0       0.79      0.85      0.82      1341
#            1       0.55      0.45      0.49       534
#
#    micro avg       0.74      0.74      0.74      1875
#    macro avg       0.67      0.65      0.66      1875
# weighted avg       0.72      0.74      0.73      1875
#
# CONFUSION MATRIX
#
# col_0              0    1
# Credit Default
# 0               1143  198
# 1                296  238

# %%
show_proba_calibration(y_train_pred_proba[:,1], y_valid, 0.4589, 0.4595)

# %%
y_p = np.array((y_train_pred_proba[:,1] > 0.4589).astype('int'))
pd.DataFrame(y_p)[0].value_counts()
# Out:
# 0    1341
# 1     534
# Name: 0, dtype: int64

# %%
get_classification_report(y_train, y_train_pred, y_valid, y_p)
# Out:
# TRAIN
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.95      0.90      4046
#            1       0.93      0.80      0.86      3158
#
#    micro avg       0.89      0.89      0.89      7204
#    macro avg       0.90      0.88      0.88      7204
# weighted avg       0.89      0.89      0.89      7204
#
# TEST
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.80      0.80      1341
#            1       0.49      0.49      0.49       534
#
#    micro avg       0.71      0.71      0.71      1875
#    macro avg       0.65      0.65      0.65      1875
# weighted avg       0.71      0.71      0.71      1875
#
# CONFUSION MATRIX
#
# col_0              0    1
# Credit Default
# 0               1071  270
# 1                270  264

# %% [markdown]
# Собираем итоговую модель:

# %%
modify_data(data, median_annual_income, median_accounts, median_months_delinquent, median_years_history, median_max_credit, 
            median_current_credit_balance, median_monthly_debt, median_bankruptcies)

# %%
null_credit_score = data[data['Credit Score'].isnull()].index
not_null__credit_score = data[data['Credit Score'].notnull()].index

# %%
null_credit_score
# Out:
# Int64Index([   5,    8,    9,   10,   16,   23,   24,   29,   33,   35,
#             ...
#             7442, 7451, 7453, 7459, 7470, 7482, 7492, 7494, 7498, 7499],
#            dtype='int64', length=1557)

# %%
not_null__credit_score
# Out:
# Int64Index([   0,    1,    2,    3,    4,    6,    7,   11,   12,   13,
#             ...
#             7486, 7487, 7488, 7489, 7490, 7491, 7493, 7495, 7496, 7497],
#            dtype='int64', length=5943)

# %%
X_test_credit = data.loc[null_credit_score, :]
X_test_credit = X_test_credit.drop('Credit Score', axis=1)
X_test_credit = X_test_credit[['Bankruptcies', 'Number of Credit Problems', 'Maximum Open Credit', 'Years of Credit History', 'Number of Open Accounts']]

# %%
y_test_credit = clf_credit.predict(X_test_credit)
y_test_credit
# Out:
# array([1227.41042071, 1282.65146174, 1149.99162763, ..., 1153.81390406,
#         992.44094213, 1361.02436094])

# %%
data.loc[null_credit_score, 'Credit Score'] = y_test_credit

# %%
data = get_balance(data, 'Credit Default')
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning:
# The current behaviour of 'Series.argmax' is deprecated, use 'idxmax'
# instead.
# The behavior of 'argmax' will be corrected to return the positional
# maximum in the future. For now, use 'series.values.argmax' or
# 'np.argmax(np.array(values))' to get the position of the maximum
# row.
#   """
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning:
# The current behaviour of 'Series.argmin' is deprecated, use 'idxmin'
# instead.
# The behavior of 'argmin' will be corrected to return the positional
# minimum in the future. For now, use 'series.values.argmin' or
# 'np.argmin(np.array(values))' to get the position of the minimum
# row.

# %%
data['Credit Default'].value_counts()
# Out:
# 0    5387
# 1    4226
# Name: Credit Default, dtype: int64

# %%
y = data['Credit Default']
X = data[features]

# %%
scaler = MinMaxScaler()
X = pd.DataFrame(scaler.fit_transform(X), columns=features)
# Out:
# D:\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:334: DataConversionWarning: Data with input dtype int32, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)

# %%
clf_rf = RandomForestClassifier(max_depth=9, max_features=9, n_estimators=200)
clf_rf.fit(X, y)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=9, max_features=9, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=200, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
modify_data(X_test, median_annual_income, median_accounts, median_months_delinquent, median_years_history, median_max_credit, 
            median_current_credit_balance, median_monthly_debt, median_bankruptcies)

# %%
null_credit_score = X_test[X_test['Credit Score'].isnull()].index
not_null__credit_score = X_test[X_test['Credit Score'].notnull()].index

# %%
null_credit_score
# Out:
# Int64Index([   0,    8,   16,   20,   27,   31,   35,   37,   38,   42,
#             ...
#             2443, 2448, 2458, 2462, 2465, 2469, 2475, 2479, 2487, 2496],
#            dtype='int64', length=513)

# %%
not_null__credit_score
# Out:
# Int64Index([   1,    2,    3,    4,    5,    6,    7,
#        1000.02926061, 1059.49175448, 1392.30440789, 1528.43750092,
#         855.17619502, 1204.17186057, 1288.2578247 ,  999.60893434,
#        1106.89234871, 1094.41475663, 1272.74597873, 1119.76284359,
#        1822.12330573, 1034.42626738, 1134.78950161, 1073.05599386,
#        1240.57216452, 1219.72678407, 1073.96293132, 1138.09753565,
#        1308.22774811, 1215.71644191, 1235.68393439, 1308.58993627,
#        1288.10940662, 1278.63671736, 1265.4813068 , 1227.10215774,
#        1050.58457366,  904.28660818,  948.33810112, 1111.10603243,
#        1178.90097417, 1163.29250247,  999.42461597,  921.22957822,
#        1387.51253431, 1168.09845744, 1150.36017353, 1019.74087023,
#         963.24046584,  899.41109136, 1269.13362438, 1319.93875289,
#         851.82708526, 1070.73231926, 1017.6083887 , 1145.48427257,
#        1113.27946713, 1244.84642262, 1169.9156903 , 1018.58288736,
#        1280.81446206, 1108.52047495, 1299.93150344, 1277.08487106,
#         934.72218741, 1231.06419969, 1199.45408605, 1219.27038601,
#        1231.79490915, 1103.06833943,  952.70322493,  965.92625918,
#        1173.6745816 , 1072.50996979, 1130.65458871, 1111.76163502,
#        1391.1638659 , 1248.72592958, 1255.58940775, 1103.60642143,
#         952.06695106,  975.67355735, 1082.5064302 , 1050.88275335,
#        1303.07898694, 1308.96631465, 1141.63784562, 1155.06956445,
#         984.33429886,  802.50917967, 1103.6732167 , 1112.98026983,
#        1392.07088652, 1025.80194756, 1072.2575866 , 1229.71287597,
#         930.14555332, 1043.24918268, 1430.72808965,  873.42326229,
#         992.44771985, 1198.57505167, 1229.65482724,  936.28781955,
#         805.61238626, 1135.81669365,  950.50711504, 1233.53153532,
#        1583.29902122, 1204.01534176, 1219.34843944, 1182.83311045,
#        1357.31891375, 1314.04327015, 1254.74801236, 1475.63579391,
#        1271.04219931, 1048.03572306, 1101.37620566, 1468.66101626,
#        1254.18863771, 1279.18560638, 1289.07004865,  904.0921334 ,
#        1214.95169122, 1123.091013  , 1197.46490897, 1157.94141719,
#         901.5712326 , 1060.3237656 , 1140.59941864,  951.84743606,
#        1498.20445128, 1187.32405649, 1105.76192746, 1196.7544682 ,
#        1414.11993658, 1122.09250256, 1155.17233085,  951.61610398,
#         912.58584035, 1164.71689636, 1130.21262359, 1282.8637821 ,
#        1116.08996582, 1131.10005224,  904.2347607 , 1255.97829595,
#         950.43081151, 1156.46521802, 1169.22614319, 1275.90863446,
#        1256.26283538,  897.85082825,  941.96921652, 1121.88288545,
#         926.04380896, 1410.41066852,  923.14064716, 1270.23256625,
#         968.23170607,  810.70474762, 1192.0649352 , 2042.7774545 ,
#        1017.4307071 , 1147.91318033,  978.02208684, 1300.91120859,
#        1155.72539749, 1207.39213296, 1360.28525227, 1123.374871  ,
#        1000.27183092])

# %%
X_test.loc[null_credit_score, 'Credit Score'] = y_test_credit

# %%
X_test = X_test[features]

# %%
scaler = MinMaxScaler()
X_test = pd.DataFrame(scaler.fit_transform(X_test), columns=features)
# Out:
# D:\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:334: DataConversionWarning: Data with input dtype int32, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)

# %%
y_test = clf_rf.predict(X_test)

# %%
y_test = pd.DataFrame(y_test, )

# %%
y_test.to_csv('IYakovleva_predictions.csv', index=None)
